# %%
import os
import pandas as pd
from causallearn.utils.cit import CIT

# %% [markdown]
# # DATA

# %%
CAUSAL = os.path.dirname(os.getcwd())

# %%
dmp = pd.read_parquet(os.path.join(CAUSAL, 'data', 'tcga_dna_mrna_path_features_and_label.parquet'))

# %% [markdown]
# # CONDITIONAL INDEPENDENCE

# %%
fkci = CIT(dmp.values, "fastkci")

# %%
fkci(0, 1, [2])
# Out:
# 0.0

# %%
fkci(0, 1)
# Out:
# 0.0
