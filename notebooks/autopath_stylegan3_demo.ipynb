# %%
# !hostname
# Out:
# wheelbarrow.cri.uchicago.edu

# %%
import os
import torch
import matplotlib.pyplot as plt

# %%
HOME = os.environ['HOME']

# %%
img = torch.load(f'{HOME}/stylegan3-slideflow/img.pt')

# %%
plt.imshow(img)
